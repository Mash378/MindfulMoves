# %%
import io
import torch
import requests
import chess.pgn
from sklearn.model_selection import train_test_split
from transformers import pipeline
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import LoraConfig, get_peft_model, TaskType
from transformers import TrainingArguments
from trl import SFTTrainer, SFTConfig

# %% [markdown]
# <h1> Data Fetching</h1>

# %%
#Get games from lichess using their rest APIs
url = "https://lichess.org/api/games/user/DrNykterstein"
params = {"max": 10000}        #Set number of games to retrieve
response = requests.get(url, params=params)      
if response.status_code == 200:
    # Proceed with processing the data
    print("Request successful")
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# Request successful

# %% [markdown]
# <h1>Parsing & Data Preprocessing</h1>

# %% [markdown]
# <h3> Preprocessing Steps </h3>
# <div>1. Start & End tags/special tokens</div>
# <div>2. tokenization</div>

# %%
#Parsing
games_data = []
games_metadata = []
pgn_data = io.StringIO(response.text)
while True:
    game = chess.pgn.read_game(pgn_data)
    if game is None:
        break
    
    white = game.headers.get("White")
    black = game.headers.get("Black")
    result = game.headers.get("Result")
    print(f"White: {white}, Black: {black}, result = {result}")

    #DATA Preprocessing
    
    # Initialize the board for this game
    board = game.board()
    san_moves = []

    # Iterate through all moves and play them on a board.
    for move in game.mainline_moves():
        #Note: use move.uci() instead of board.san(move) for moves in UCI format
        san_moves.append(board.san(move)) # Convert to SAN string
        board.push(move)                 # Update board state for the next move
    
    # Join with spaces for NLP tokenization
    move_sequence = " ".join(san_moves)
    games_data.append(move_sequence)
    games_metadata.append({
        'white': white,
        'black': black,
        'moves': move_sequence
    })
# Out:
# White: DrDrunkenstein, Black: Natethegreat12, result = 1-0
# White: DrDrunkenstein, Black: saeed7499, result = 0-1
# White: dugong161, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: IckerElTigre, result = 1-0
# White: Natethegreat12, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Zhigalko_Sergei, result = 0-1
# White: Gokerkan, Black: DrDrunkenstein, result = 1-0
# White: Zhigalko_Sergei, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Tayka, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: TerryR2, result = 1-0
# White: Wild-King91, Black: DrDrunkenstein, result = 1-0
# White: liczner, Black: DrDrunkenstein, result = 0-1
# White: BlueGreensun, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: BabaRamdev, result = 1-0
# White: DrDrunkenstein, Black: caching, result = 1-0
# White: DrDrunkenstein, Black: TerryR2, result = 1-0
# White: DrDrunkenstein, Black: Wild-King91, result = 1-0
# White: alireza2003, Black: DrDrunkenstein, result = 0-1
# White: TerryR2, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: Zhigalko_Sergei, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: SaraciNderim, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: kiketf, result = 1-0
# White: DrDrunkenstein, Black: pochtalionPechkin, result = 1-0
# White: DrDrunkenstein, Black: PulpanJ, result = 1-0
# White: PchelkinVK, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: RebeccaHarris, result = 1-0
# White: opperwezen, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: RebeccaHarris, result = 0-1
# White: DrDrunkenstein, Black: BabaRamdev, result = 1-0
# White: TerryR2, Black: DrDrunkenstein, result = 1-0
# White: RebeccaHarris, Black: DrDrunkenstein, result = 1-0
# White: Astramariy, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: MasterAmy, Black: DrDrunkenstein, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: AstanehChess, result = 1-0
# White: DrDrunkenstein, Black: Macrofago, result = 1-0
# White: DrDrunkenstein, Black: mutdpro, result = 0-1
# White: srinathbaggins, Black: DrDrunkenstein, result = 0-1
# White: gsvc, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Macrofago, result = 1-0
# White: AstanehChess, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: mutdpro, result = 1-0
# White: TerryR2, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: boorchess, result = 1-0
# White: DrDrunkenstein, Black: msb2, result = 0-1
# White: Saaker, Black: DrDrunkenstein, result = 0-1
# White: opperwezen, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: Astramariy, result = 1-0
# White: CreativePlayer007, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: dulemaster, result = 1-0
# White: DrDrunkenstein, Black: thujer, result = 1-0
# White: ethereumclassic, Black: DrDrunkenstein, result = 0-1
# White: TerryR2, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: DrDrunkenstein, Black: Zaven_ChessMood, result = 1-0
# White: Ivan_Nevyansk, Black: DrDrunkenstein, result = 0-1
# White: Kubas92, Black: DrDrunkenstein, result = 0-1
# White: mutdpro, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: Mishka_The_Great, result = 1-0
# White: Mishka_The_Great, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Mishka_The_Great, result = 1-0
# White: Mishka_The_Great, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: DrDrunkenstein, Black: kiketf, result = 1-0
# White: opperwezen, Black: DrDrunkenstein, result = 0-1
# White: Astramariy, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: opperwezen, result = 1/2-1/2
# White: JessePinkman, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: Macrofago, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: kapaccino, result = 1-0
# White: BabaRamdev, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: LeonLivaic, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: dexter29, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: JungleViking, result = 1-0
# White: Macrofago, Black: DrDrunkenstein, result = 0-1
# White: JessePinkman, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: BabaRamdev, result = 0-1
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 0-1
# White: BabaRamdev, Black: DrDrunkenstein, result = 1/2-1/2
# White: Macrofago, Black: DrDrunkenstein, result = 1-0
# White: GMVallejo, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: BabaRamdev, result = 1/2-1/2
# White: DrDrunkenstein, Black: DonMateo85, result = 1-0
# White: UnVieuxMonsieur, Black: DrDrunkenstein, result = 0-1
# White: BabaRamdev, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: SaraciNderim, result = 1-0
# White: DrDrunkenstein, Black: alireza2003, result = 1-0
# White: GeorgMeier, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: BabaRamdev, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: JungleViking, result = 1-0
# White: Arka50, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: caching, result = 1-0
# White: Nirvana95, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: msb2, result = 1/2-1/2
# White: DrDrunkenstein, Black: Nirvana95, result = 1-0
# White: cemilchess, Black: DrDrunkenstein, result = 0-1
# White: Hawk20, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: irakliberadze, result = 1-0
# White: DrDrunkenstein, Black: ViejoTortuga, result = 0-1
# White: BabaRamdev, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: Weetik, result = 1-0
# White: irakliberadze, Black: DrDrunkenstein, result = 1-0
# White: caching, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Gokerkan, result = 1-0
# White: GeorgMeier, Black: DrDrunkenstein, result = 0-1
# White: cukus, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: caching, result = 0-1
# White: DrDrunkenstein, Black: BabaRamdev, result = 1-0
# White: dmitrij_IM, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Drthebigboss, result = 1-0
# White: DrDrunkenstein, Black: kiketf, result = 1-0
# White: Barron123, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Distinctive, result = 0-1
# White: Horobetz, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Rain_Man, result = 0-1
# White: BabaRamdev, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: MrGreen08, result = 1-0
# White: Doomfist, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Night-King96, result = 0-1
# White: UnVieuxMonsieur, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 1-0
# White: UnVieuxMonsieur, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 0-1
# White: UnVieuxMonsieur, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 1-0
# White: UnVieuxMonsieur, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 1-0
# White: UnVieuxMonsieur, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 1-0
# White: UnVieuxMonsieur, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 1-0
# White: Nirvana95, Black: DrDrunkenstein, result = 0-1
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: msb2, result = 1-0
# White: mutdpro, Black: DrDrunkenstein, result = 0-1
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: VerdeNotte, result = 1-0
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: msb2, Black: DrDrunkenstein, result = 0-1
# White: alireza2003, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: msb2, result = 1-0
# White: Gokerkan, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: mutdpro, result = 1-0
# White: DrDrunkenstein, Black: CleverTacticButFail, result = 1-0
# White: DrDrunkenstein, Black: AstanehChess, result = 1-0
# White: CleverTacticButFail, Black: DrDrunkenstein, result = 0-1
# White: RebeccaHarris, Black: DrDrunkenstein, result = 0-1
# White: TwelveTeen, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: DrDrunkenstein, Black: mutdpro, result = 1-0
# White: alireza2003, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 0-1
# White: alireza2003, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: Nirvana95, result = 0-1
# White: JseMartinez, Black: DrDrunkenstein, result = 1/2-1/2
# White: Johanssc, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: CleverTacticButFail, result = 1-0
# White: alireza2003, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: TwelveTeen, result = 1-0
# White: DrDrunkenstein, Black: RebeccaHarris, result = 1-0
# White: msb2, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: alireza2003, result = 1-0
# White: msb2, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Gokerkan, result = 1-0
# White: Pap-G, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: JoranvdS, result = 1-0
# White: opperwezen, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: GeorgMeier, result = 1-0
# White: DrDrunkenstein, Black: alireza2003, result = 1-0
# White: Nirvana95, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheWarning, result = 1/2-1/2
# White: DrDrunkenstein, Black: CleverTacticButFail, result = 0-1
# White: Nirvana95, Black: DrDrunkenstein, result = 1-0
# White: Pap-G, Black: DrDrunkenstein, result = 0-1
# White: RebeccaHarris, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: Ogrilla, result = 1-0
# White: DrDrunkenstein, Black: CleverTacticButFail, result = 1-0
# White: Elda64, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: MeneerMandje, result = 1-0
# White: GeorgMeier, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheWarning, result = 0-1
# White: JessePinkman, Black: DrDrunkenstein, result = 0-1
# White: CleverTacticButFail, Black: DrDrunkenstein, result = 0-1
# White: yoseph2013, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: DrDrunkenstein, Black: Night-King96, result = 1-0
# White: Macrofago, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: CleverTacticButFail, result = 0-1
# White: lovlas, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: MarcTheSpark, result = 1-0
# White: DrDrunkenstein, Black: JoranvdS, result = 1-0
# White: JseMartinez, Black: DrDrunkenstein, result = 1/2-1/2
# White: kiketf, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: mutdpro, result = 1-0
# White: DrDrunkenstein, Black: Mig_31, result = 1-0
# White: RebeccaHarris, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: Night-King96, result = 1-0
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheWarning, result = 0-1
# White: TheWarning, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: TheWarning, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheWarning, result = 1/2-1/2
# White: TheWarning, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: DrDrunkenstein, Black: GeorgMeier, result = 0-1
# White: Hawk20, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 1-0
# White: Azzaro25, Black: DrDrunkenstein, result = 0-1
# White: UnVieuxMonsieur, Black: DrDrunkenstein, result = 0-1
# White: Macrofago, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 0-1
# White: DrDrunkenstein, Black: RebeccaHarris, result = 1-0
# White: UnVieuxMonsieur, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Mlchael, result = 1-0
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 1-0
# White: opperwezen, Black: DrDrunkenstein, result = 0-1
# White: RebeccaHarris, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: DrDrunkenstein, Black: Mlchael, result = 1-0
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: GeorgMeier, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Ogrilla, result = 0-1
# White: RebeccaHarris, Black: DrDrunkenstein, result = 1-0
# White: Macrofago, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: Fins, result = 1-0
# White: RebeccaHarris, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: Ogrilla, Black: DrDrunkenstein, result = 0-1
# White: Hawk20, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Mlchael, result = 1-0
# White: Rain_Man, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Macrofago, result = 1-0
# White: Fondip, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Macrofago, result = 1-0
# White: opperwezen, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Mlchael, result = 1-0
# White: TwelveTeen, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: mutdpro, result = 1/2-1/2
# White: DrDrunkenstein, Black: Mlchael, result = 1-0
# White: Macrofago, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: Arka50, result = 1-0
# White: kiketf, Black: DrDrunkenstein, result = 0-1
# White: Night-King96, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: mutdpro, result = 1-0
# White: RebeccaHarris, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: Creep30, result = 1-0
# White: Fondip, Black: DrDrunkenstein, result = 0-1
# White: Creep30, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: JessePinkman, result = 1-0
# White: DrDrunkenstein, Black: mutdpro, result = 1-0
# White: JessePinkman, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Fondip, result = 1-0
# White: DrDrunkenstein, Black: Nirvana95, result = 1-0
# White: Macrofago, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: Creep30, result = 1-0
# White: beatles_21, Black: DrDrunkenstein, result = 0-1
# White: RebeccaHarris, Black: DrDrunkenstein, result = 0-1
# White: Night-King96, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Fondip, result = 1-0
# White: DrDrunkenstein, Black: condansator3, result = 1-0
# White: opperwezen, Black: DrDrunkenstein, result = 0-1
# White: steel_rocket, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: UnVieuxMonsieur, result = 1-0
# White: DrDrunkenstein, Black: Azzaro25, result = 1-0
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: DrDrunkenstein, Black: Ogrilla, result = 1-0
# White: steel_rocket, Black: DrDrunkenstein, result = 0-1
# White: the2016willbemine, Black: DrDrunkenstein, result = 0-1
# White: Arka50, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Night-King96, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1/2-1/2
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: larso, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1/2-1/2
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: larso, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: DrDrunkenstein, Black: Mayjin, result = 1-0
# White: Krantss, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Danirod, result = 0-1
# White: Sigma_Tauri, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: Nyxnyxnyxnyxnyx, result = 0-1
# White: Sun-Fire, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: AstanehChess, result = 1-0
# White: DrDrunkenstein, Black: Mishka_The_Great, result = 0-1
# White: Krantss, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: Morphy123, Black: DrDrunkenstein, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 1/2-1/2
# White: MeikeSchlecker, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: Mishka_The_Great, result = 1-0
# White: DrDrunkenstein, Black: MeikeSchlecker, result = 1-0
# White: Morphy123, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: DrDrunkenstein, Black: MennyHobber, result = 1-0
# White: opperwezen, Black: DrDrunkenstein, result = 0-1
# White: Krantss, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: TheMeatOnBone, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 0-1
# White: Barron123, Black: DrDrunkenstein, result = 1/2-1/2
# White: Nectarine, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: dragonwelb, result = 0-1
# White: MennyHobber, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: DrDrunkenstein, Black: TheMeatOnBone, result = 0-1
# White: DrDrunkenstein, Black: Crew64, result = 1-0
# White: Lil_Mark, Black: DrDrunkenstein, result = 0-1
# White: Hardian_Rochild, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: DrDrunkenstein, Black: cxb5, result = 1-0
# White: Hardian_Rochild, Black: DrDrunkenstein, result = 0-1
# White: Morphy123, Black: DrDrunkenstein, result = 1-0
# White: BermudaGhostShip, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: raastin, result = 1/2-1/2
# White: gkbe, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Mishka_The_Great, result = 1-0
# White: gkbe, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: Nectarine, result = 0-1
# White: DrDrunkenstein, Black: mknz, result = 1-0
# White: Simba7, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: ratbadger1, result = 1-0
# White: DrDrunkenstein, Black: bidon67, result = 1-0
# White: DrDrunkenstein, Black: orxan877, result = 1-0
# White: angelgab3, Black: DrDrunkenstein, result = 0-1
# White: tahayildirim, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: shunzhu22, result = 1-0
# White: VaibhavRana2003, Black: DrDrunkenstein, result = 0-1
# White: Kidefence, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: OMALEY, result = 1-0
# White: Secereli, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: spurv, result = 1-0
# White: nissou-ach, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Sh_Vladimir, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: penguingim1, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1/2-1/2
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 0-1
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: penguingim1, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1/2-1/2
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: chessbrahs, result = 1-0
# White: chessbrahs, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: NorwegianNinja, result = 1-0
# White: TheRigos, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: LarryFDavid, result = 1-0
# White: TheRigos, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: WaWaWeeWa, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheRigos, result = 1-0
# White: TheMeatOnBone, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: muran29, result = 0-1
# White: chessbrahs, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: jlhammer, result = 1-0
# White: muran29, Black: DrDrunkenstein, result = 0-1
# White: Krisovski, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: larso, result = 1-0
# White: DrDrunkenstein, Black: JonahB94, result = 0-1
# White: Krisovski, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: FlyInSky, result = 1-0
# White: Elda64, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: muran29, result = 1-0
# White: Eldrail, Black: DrDrunkenstein, result = 1/2-1/2
# White: jlhammer, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: Mishka_The_Great, result = 1-0
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: DrDrunkenstein, Black: Mayjin, result = 1-0
# White: muran29, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: TheRigos, result = 1-0
# White: Sicilian_Dragon2018, Black: DrDrunkenstein, result = 0-1
# White: NorwegianNinja, Black: DrDrunkenstein, result = 0-1
# White: larso, Black: DrDrunkenstein, result = 0-1
# White: JonahB94, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: LordBendtner99, result = 1-0
# White: DrDrunkenstein, Black: Eldrail, result = 1-0
# White: JonahB94, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Chillkroete77, result = 1-0
# White: DrDrunkenstein, Black: Enricodinho, result = 1-0
# White: muran29, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: SecJacek, result = 1-0
# White: DrDrunkenstein, Black: HrvojeZagreb, result = 1-0
# White: LornerAcosta, Black: DrDrunkenstein, result = 1-0
# White: GodlikeMoves, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: MarklarMarklar, result = 1-0
# White: PeterPun3, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: LordBendtner99, result = 1-0
# White: Rickyrich, Black: DrDrunkenstein, result = 0-1
# White: Chillkroete77, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Jaberi, result = 1-0
# White: tahayildirim, Black: DrDrunkenstein, result = 0-1
# White: Krantss, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: mfm008, result = 1-0
# White: DrDrunkenstein, Black: CoJOnUdO, result = 1-0
# White: arcymisio, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: eie24, result = 1-0
# White: hobbitRus, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: dreagerpair, result = 1-0
# White: DrDrunkenstein, Black: ERMAL111, result = 1-0
# White: Arkimede, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: quasar, result = 1-0
# White: DrDrunkenstein, Black: Girbidas, result = 1-0
# White: Zeitfuge, Black: DrDrunkenstein, result = 0-1
# White: Hani007, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: Arka50, Black: DrDrunkenstein, result = 0-1
# White: dmitrij_IM, Black: DrDrunkenstein, result = 1/2-1/2
# White: DrDrunkenstein, Black: Arka50, result = 1-0
# White: DrDrunkenstein, Black: MeneerMandje, result = 1-0
# White: JoranvdS, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: JoranvdS, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: FaridFirmansyah, result = 1-0
# White: A_Kukhmazov, Black: DrDrunkenstein, result = 0-1
# White: taheryoseph, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: dmitrij_IM, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: JoranvdS, result = 1-0
# White: dmitrij_IM, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: alireza2003, result = 0-1
# White: DrDrunkenstein, Black: dmitrij_IM, result = 1-0
# White: jlhammer, Black: DrDrunkenstein, result = 0-1
# White: opperwezen, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: LittlePeasant, result = 1-0
# White: opperwezen, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Nirvana95, result = 1-0
# White: DrDrunkenstein, Black: Bombegranate, result = 1-0
# White: dmitrij_IM, Black: DrDrunkenstein, result = 0-1
# White: TheWarning, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: jlhammer, result = 1-0
# White: Bombegranate, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: alireza2003, result = 1/2-1/2
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: dmitrij_IM, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: zvonokchess, result = 1-0
# White: toivok, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: alireza2003, result = 1-0
# White: VerdeNotte, Black: DrDrunkenstein, result = 0-1
# White: Arka50, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: penguingim1, result = 1-0
# White: DrDrunkenstein, Black: AstanehChess, result = 1-0
# White: DrDrunkenstein, Black: taheryoseph, result = 1/2-1/2
# White: kapaccino, Black: DrDrunkenstein, result = 0-1
# White: DefendingTheUniverse, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Bombegranate, result = 1-0
# White: opperwezen, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: alireza2003, result = 1-0
# White: off_white, Black: DrDrunkenstein, result = 0-1
# White: MeneerMandje, Black: DrDrunkenstein, result = 0-1
# White: taheryoseph, Black: DrDrunkenstein, result = 1-0
# White: DrDrunkenstein, Black: Arka50, result = 1-0
# White: toivok, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Bombegranate, result = 1-0
# White: DrDrunkenstein, Black: TheWarning, result = 1-0
# White: Elda64, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Bombegranate, result = 1-0
# White: Arka50, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: toivok, result = 1-0
# White: MeneerMandje, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Ogrilla, result = 1-0
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: MeneerMandje, Black: DrDrunkenstein, result = 1/2-1/2
# White: SHREKDAVID, Black: DrDrunkenstein, result = 0-1
# White: DefendingTheUniverse, Black: DrDrunkenstein, result = 0-1
# White: MeneerMandje, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: zvonokchess, result = 1-0
# White: DrDrunkenstein, Black: opperwezen, result = 1-0
# White: Morgran, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: MeneerMandje, result = 0-1
# White: DrDrunkenstein, Black: Arka50, result = 1-0
# White: CreativePlayer007, Black: DrDrunkenstein, result = 0-1
# White: DrDrunkenstein, Black: Amirreza_p, result = 1-0
# White: Fireglass, Black: DrDrunkenstein, result = 0-1

# %% [markdown]
# <h1>Training</h1>

# %%
from datasets import Dataset
#Split Data into Training + Test
train_data, test_data, train_meta, test_meta = train_test_split(games_data, games_metadata, test_size=0.3, random_state=42)

print(f"Training: {len(train_data)}")
print(f"Testing: {len(test_data)}")

train_dataset = Dataset.from_list([{"text": seq} for seq in train_data])
# Out:
# Training: 692
# Testing: 297

# %%
device = 0 if torch.cuda.is_available() else -1
model_name = "Waterhorse/chessgpt-base-v1"
#model_name = "derickio/chess-gpt-4.5M"

#Load the model and the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
model = AutoModelForCausalLM.from_pretrained(model_name)

engine = pipeline(task="text-generation", model=model, tokenizer=tokenizer, device=device)
# Out:
# Loading weights:   0%|          | 0/388 [00:00<?, ?it/s]

# %%
#Fine Tuning model use LoRA Technique
lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["query_key_value", "dense"],  #"query_key_value", "dense"
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.CAUSAL_LM,
)

#Applying LoRA to the model
lora_model = get_peft_model(model, lora_config)
lora_model.print_trainable_parameters()

training_args = SFTConfig(
    per_device_train_batch_size=4,       
    gradient_accumulation_steps=8,     
    warmup_steps=200,                   
    num_train_epochs=1,             
    learning_rate=2e-4,                   
    fp16=False,  
    bf16=False,
    logging_steps=50,
    output_dir="./magnus-chessGPT",
    save_steps=500,
    dataset_text_field="text",
    packing=True,                         
)

trainer = SFTTrainer(
    model=lora_model,
    train_dataset=train_dataset,
    args=training_args,          # SFTConfig replaces both TrainingArguments and SFTTrainer params
)

trainer.train()
# Out:
# trainable params: 7,864,320 || all params: 2,783,728,640 || trainable%: 0.2825
# Padding-free training is enabled, but the attention implementation is not set to a supported flash attention variant. Padding-free training flattens batches into a single sequence, and only the following implementations are known to reliably support this: flash_attention_2, flash_attention_3, kernels-community/flash-attn2, kernels-community/flash-attn3, kernels-community/vllm-flash-attn3. Using other implementations may lead to unexpected behavior. To ensure compatibility, set `attn_implementation` in the model configuration to one of these supported options or verify that your attention mechanism can handle flattened sequences.
# You are using packing, but the attention implementation is not set to a supported flash attention variant. Packing gathers multiple samples into a single sequence, and only the following implementations are known to reliably support this: flash_attention_2, flash_attention_3, kernels-community/flash-attn2, kernels-community/flash-attn3, kernels-community/vllm-flash-attn3. Using other implementations may lead to cross-contamination between samples. To avoid this, either disable packing by setting `packing=False`, or set `attn_implementation` in the model configuration to one of these supported options.
# Adding EOS to train dataset:   0%|          | 0/692 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/692 [00:00<?, ? examples/s]
# Packing train dataset:   0%|          | 0/692 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 1}.
# c:\Users\mashr\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)

# %% [markdown]
# <h1>Model Evaluation</h1>

# %%
from tqdm import tqdm

def extract_player_moves (game_meta, player_name="DrNykterstein"):
    white = game_meta['white']
    black = game_meta['black']
    moves = game_meta['moves'].split()

    # Determine which color the player was
    if white == player_name:
        color = "white"
        start_idx = 0
    elif black == player_name:
        color = "black"
        start_idx = 1
    else:
        return []

    player_positions = []

    for i in range(start_idx, len(moves), 2):
        context = " ".join(moves[:i])       #position
        if not context.strip():
          continue
        target_move = moves[i]              #move made by player

        player_positions.append((context, target_move))

    return player_positions

def prepare_evaluation_data(test_metadata, player_name="DrNykterstein"):
    """Prepare all test positions for evaluation."""
    all_positions = []

    for game_meta in test_metadata:
        positions = extract_player_moves(game_meta, player_name)
        all_positions.append(positions)

    return all_positions

def calculate_move_accuracy (model, tokenizer, positions, k=1):
    correct = 0
    total = len(positions)

    device = next(model.parameters()).device    #
    model.eval()            #Set model in evaluation mode

    for context, actual_move in tqdm(positions, desc=f"Top-{k} Accuracy"):
        inputs = tokenizer(context, return_tensors="pt", truncation=True, max_length=512).to(device)

        # Generate top-k predictions
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=10,
                num_beams=k,
                num_return_sequences=k,
                early_stopping=True,
                pad_token_id=tokenizer.eos_token_id,
                do_sample=False
            )

        # Decode predictions
        predictions = []
        for output in outputs:
            new_tokens = output[inputs['input_ids'].shape[1]:]
            pred_text = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
            first_move = pred_text.split()[0] if pred_text else ""
            predictions.append(first_move)

        # Check if actual move is in top-k predictions
        if actual_move in predictions:
            correct += 1

    accuracy = correct / total if total > 0 else 0
    return accuracy, total

# %%
print("EVALUATION STARTED")

player_name = "DrNykterstein"
positions = [pos for game in prepare_evaluation_data(test_meta, player_name) for pos in game]
print(f"Total positions to evaluate: {len(positions)}")

# 1. Move Accuracy
print("Calculating Top-1 Move Accuracy...")
top1_acc, n_pos = calculate_move_accuracy(lora_model, tokenizer, positions, k=1)
    
print("Calculating Top-3 Move Accuracy...")
top3_acc, _ = calculate_move_accuracy(lora_model, tokenizer, positions, k=3)

print("EVALUATION RESULTS")
print(f"Positions Evaluated:  {n_pos}")
print(f"Top-1 Move Accuracy:  {top1_acc:.2%} ({int(top1_acc * n_pos)}/{n_pos} correct)")
print(f"Top-3 Move Accuracy:  {top3_acc:.2%} ({int(top3_acc * n_pos)}/{n_pos} correct)")

# %%
lora_model.save_pretrained("./modelConfig")
tokenizer.save_pretrained("./modelConfig")
